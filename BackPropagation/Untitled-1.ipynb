# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("LossFunction_8x8.txt",names=["lossfunction"])
plt.scatter(df.index,df.lossfunction)
plt.xlabel('Iteration')
plt.ylabel('Loss function')
plt.ylim(0,0.1)
# Out:
# (0.0, 0.1)
